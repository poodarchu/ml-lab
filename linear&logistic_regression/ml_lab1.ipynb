# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

from sklearn.linear_model import LinearRegression

# %%
def float_(str_):
    col = []
    for i in str_:
        temp = float(i)
        col.append(temp)
    np.append(res, col)
    return res

# %%
data = np.loadtxt('/Users/poodar/Downloads/2016-11-1-mllab/code/logistic_x.txt', delimiter=',')
print data
# Out:
# [[ 1.3432504  -1.3311479 ]
#  [ 1.8205529  -0.6346681 ]
#  [ 0.98632067 -1.8885762 ]
#  [ 1.9443734  -1.635452  ]
#  [ 0.97673352 -1.3533151 ]
#  [ 1.9458584  -2.0443278 ]
#  [ 2.1075153  -2.1256684 ]
#  [ 2.070373   -2.4634101 ]
#  [ 0.86864964 -2.4119348 ]
#  [ 1.8006594  -2.7739689 ]
#  [ 3.1283787  -3.4452432 ]
#  [ 3.0947429  -3.6446145 ]
#  [ 2.9086652  -4.0065037 ]
#  [ 2.6770338  -3.0198592 ]
#  [ 2.7458671  -2.7100561 ]
#  [ 4.1714647  -3.4622482 ]
#  [ 3.931322   -2.1099044 ]
#  [ 4.378687   -2.3804743 ]
#  [ 4.8016565  -3.3803344 ]
#  [ 4.166105   -2.8138844 ]
#  [ 2.4670141  -1.6108444 ]
#  [ 3.4826743  -1.5533872 ]
#  [ 3.3652482  -1.8164936 ]
#  [ 2.8772788  -1.8511689 ]
#  [ 3.1090444  -1.6384946 ]
#  [ 2.2183701   0.07427956]
#  [ 1.9949873   0.16268659]
#  [ 2.9500308   0.01687302]
#  [ 2.0216009   0.17227387]
#  [ 2.0486921  -0.63581041]
#  [ 0.87548563 -0.54586168]
#  [ 0.57079941 -0.03327866]
#  [ 1.4266468  -0.75288337]
#  [ 0.72265633 -0.8669193 ]
# ...

# %%
X = np.c_[np.ones(data.shape[0]), data[:]]
X
# Out:
# array([[ 1.        ,  1.3432504 , -1.3311479 ],
#        [ 1.        ,  1.8205529 , -0.6346681 ],
#        [ 1.        ,  0.98632067, -1.8885762 ],
#        [ 1.        ,  1.9443734 , -1.635452  ],
#        [ 1.        ,  0.97673352, -1.3533151 ],
#        [ 1.        ,  1.9458584 , -2.0443278 ],
#        [ 1.        ,  2.1075153 , -2.1256684 ],
#        [ 1.        ,  2.070373  , -2.4634101 ],
#        [ 1.        ,  0.86864964, -2.4119348 ],
#        [ 1.        ,  1.8006594 , -2.7739689 ],
#        [ 1.        ,  3.1283787 , -3.4452432 ],
#        [ 1.        ,  3.0947429 , -3.6446145 ],
#        [ 1.        ,  2.9086652 , -4.0065037 ],
#        [ 1.        ,  2.6770338 , -3.0198592 ],
#        [ 1.        ,  2.7458671 , -2.7100561 ],
#        [ 1.        ,  4.1714647 , -3.4622482 ],
#        [ 1.        ,  3.931322  , -2.1099044 ],
#        [ 1.        ,  4.378687  , -2.3804743 ],
#        [ 1.        ,  4.8016565 , -3.3803344 ],
#        [ 1.        ,  4.166105  , -2.8138844 ],
# ...

# %%
labelsFile = np.loadtxt('/Users/poodar/Downloads/2016-11-1-mllab/code/logistic_y.txt')

# %%
Y = np.c_[labelsFile[:]]
print type(Y)
Y.shape
Y = np.array(Y)
# Out:
# <type 'numpy.ndarray'>

# %%
theta = np.linalg.inv(X.T.dot(X)).dot(X.T.dot(Y))

# %%
theta
# Out:
# array([[-0.75989895],
#        [ 0.21807269],
#        [ 0.30869087]])

# %%
# plt.plot(X[Y<0][1:2], X[Y<0][-1], c='b', marker='+', linewidth=2)
# plt.plot(X[Y>0][1:2], X[Y>0][-1], c='r', marker='x', linewidth=2)

print type(Y)
# print Y == -1
print X.shape
print Y.shape

temp = Y==-1
# temp = temp.T

type(temp)
        
# plt.plot(X[Y==-1][-2], X[Y==-1,-1], c='b', marker='+', linewidth=2)
# plt.plot(X[Y==1, -2], X[Y==1, -1], c='r', marker='x', linewidth=2)

# x1 = np.arange(min(X[:,-2]), max(X[:,-2]), 0.01)

# x2 = -(theta[0] / theta[2]) - (theta[1] / theta[2]) * x1

# plt.plot(x1, x2, label='Linear regression')
# plt.xlim(min(x1), max(x1))
# plt.xlabel('x1')
# plt.ylabel('y1')

# plt.show()
# Out:
# <type 'numpy.ndarray'>
# (99, 3)
# (99, 1)
# numpy.ndarray
